# %%
import pickle
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
scx=pickle.load(open("scaler.sav","rb"))
preinput=scx.transform([[1500,15000,7000,0,9]])
loaded_model=pickle.load(open("finalized_model_svr_sav",'rb'));
result=loaded_model.predict(preinput)

# %%
scy=pickle.load(open("scaler.sav","rb"))
preinput=scy.transform([[1700,33000,10000,0,100]])
loaded_model=pickle.load(open("finalized_model_svr_sav",'rb'));
result=loaded_model.predict(preinput)

# %%
preinput=scx.transform([[1500,15000,7000,0,9]])

# %%
preinput
# Out:
# array([[-2.52774563, -2.21388529, -2.3998766 , -2.562619  , -2.56240976]])

# %%
preinput1=scy.transform([[1700,33000,10000,0,100]])

# %%
preinput1
# Out:
# array([[-2.52309584, -1.79540483, -2.33012986, -2.562619  , -2.5602941 ]])

# %%
result
# Out:
# array([108225.7831216])

# %%
preoutput=scy.inverse_transform([result])

# %%
preoutput
# Out:
# array([[4.65520006e+09]])
